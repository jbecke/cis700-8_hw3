# %%
# !pip install transformers  # Used to compute BERT embeddings.
# !pip install textblob # for sentiment classification

import IPython.display
IPython.display.clear_output()

# %%
import numpy as np
import copy
import csv
import random
import IPython.display

# from tqdm.autonotebook import tqdm
from tqdm import tqdm
import pickle
import nltk
import string
nltk.download('punkt')

import tensorflow as tf
tf.enable_v2_behavior()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# # Natural Language Understanding
# When you read a story, you understand many things about it.
# You understand who the characters are, where the story is taking place, and the events that have happened so far. Given your comprehension of the story so far and your common-sense understanding of the world, you can often predict what will or will not happen next.
#
# This skill is innate for you, but the ability to guess at likely future directions for a story is actually a really difficult task to teach computers. In this homework, you will be exploring two tasks that were designed to evaluate how well computers can tell a probable story continuation from an improbable one.

# %% [markdown]
# # ROCStories
# The [ROCStories task](https://cs.rochester.edu/nlp/rocstories/) involves predicting which sentence best ends a short story. The stories look something like this:
#
# **Story**
# ```
# Dorothy's cat was pregnant.
# She didn't know how it happened.
# She convinced the family to keep the kittens.
# It wound up having 7 kittens.
# ```
# **Candidate Ending 1**
# ```
# Dorothy made sure to buy lots of cat food.
# ```
# **Candidate Ending 2**
# ```
# Dorothy went to the pet store and bought a new hamster.
# ```
#
# The bad ending sentences are designed to be on topic but clearly incorrect to a human. Despite Ending 2 mentioning a pet store, you should have quickly guessed that Ending 1 is the correct one.
#
# The tricky part about ROCStories is that the training set only contains 5-sentence stories with good ending sentences.
# However, at test time you see two possible 5th sentences and need to classify which is better.
# You can read up on the dataset and how it was collected in the [paper introducing the dataset](https://www.aclweb.org/anthology/N16-1098.pdf).
#
# In those homework, you will investigate how a very simple sentiment-based approach can get reasonable accuracy at this task, revealing the challenges behind designing datasets and tasks for evaluating natural language and commonsense understanding.
#
# You will also train a neural network to perform the task, hopefully achieving higher accuracy.
#
# Lastly, if you choose to, you can submit to the official leaderboard for extra credit.

# %% [markdown]
# ### Download the data
# There are two versions of the ROCStories dataset. After its original 2016 release, researchers noticed problematic biases in the data. The 2017/2018 version was an attempt to resolve these biases. You should report your results on both the 2016 and 2018 validation sets, as well as the 2016 test set. (The 2018 test set is available for download online as well, but the labels for it are still being withheld.)

# %%
### Download the data
# !mkdir rocstories_data
# !wget -nc -O rocstories_data/train2017.csv https://docs.google.com/spreadsheets/d/1emH8KL8NVCCumZc2oMu-3YqRWddD3AqZEHvNqMdfgKA/export?format=csv
# !wget -nc -O rocstories_data/valid2018.csv https://docs.google.com/spreadsheets/d/1F9vtluzD3kZOn7ULKyMQZfoRnSRzRnnaePyswkRqIdY/export?format=csv
# !wget -nc -O rocstories_data/valid2016.csv https://docs.google.com/spreadsheets/d/1FkdPMd7ZEw_Z38AsFSTzgXeiJoLdLyXY_0B_0JIJIbw/export?format=csv
# !wget -nc -O rocstories_data/test2016.csv  https://docs.google.com/spreadsheets/d/11tfmMQeifqP-Elh74gi2NELp0rx9JMMjnQ_oyGKqCEg/export?format=csv

IPython.display.clear_output()  # Clear the stdout/

def read_rocstories_valid_csv(path):
  examples = []
  with open(path) as f:
    reader = csv.DictReader(f)
    for line in reader:
      context = [line['InputSentence1'], line['InputSentence2'],
                 line['InputSentence3'], line['InputSentence4']]
      option_0 = line['RandomFifthSentenceQuiz1']
      option_1 = line['RandomFifthSentenceQuiz2']
      label = int(line['AnswerRightEnding']) - 1
      examples.append({'context': context, 
                       'options': [option_0, option_1],
                       'label': label})
  return examples

def read_rocstories_train_csv(path):
  examples = []
  with open(path) as f:
    reader = csv.DictReader(f)
    for line in reader:
      story = [line['sentence1'], line['sentence2'],
               line['sentence3'], line['sentence4'],
               line['sentence5']]
      examples.append({'story': story})
  return examples

train_data = read_rocstories_train_csv('/content/rocstories_data/train2017.csv')
valid_2016_data = read_rocstories_valid_csv('/content/rocstories_data/valid2016.csv')
valid_2018_data = read_rocstories_valid_csv('/content/rocstories_data/valid2018.csv')
test_2016_data = read_rocstories_valid_csv('/content/rocstories_data/test2016.csv')

# %% [markdown]
# Here's what an example in the train dataset looks like:
# ```
# > print(train_data[123])
# {'story': ["Sam's dog Rex escaped from their yard.",
#            'Sam was distraught.',
#            'He went out calling for Rex.',
#            'Then he saw Rex come running up the street!',
#            'Sam was so relieved, he almost cried!']}
# ```
# Here's what an example in one of the validation datasets looks like:
# ```
# > print(valid_2016_data[123])
# {'context': ["Jen got sent to her aunt's for the summer.",
#             'She hated the thought of being away from her local library all summer.',
#             'She took a few books with her but she would go through those quickly.',
#             'When she arrived her aunt took her into a special room in her home.'],
#  'label': 1,
#  'options': ['Jen saw her books burning in the fireplace.',
#              'The room was full of shelves of books that appealed to girls.']}
# ```

# %% [markdown]
# ### Classify with sentiment analysis
# After the ROCStories dataset was released in 2016, researchers soon realized that it has undesired biases. The correct next sentences tends to be more positive than the incorrect next sentences. An updated version of the dataset was released in 2018 that attempted to eliminate this bias.
#
# Implement a function that makes a prediction based on sentiment.
# You can use either [AllenNLP](https://demo.allennlp.org/sentiment-analysis) or [TextBlob](https://textblob.readthedocs.io/en/dev/quickstart.html#sentiment-analysis).
# Your function should compute the sentiment of each 5th sentence option and predict the one with the more positive sentiment.
#
# **In your report, list the validation and test accuracies you get with your sentiment classifier. Also show a couple of negative examples where the model incorrectly,**
#
# *Hint: We were able to get over 60\% accuracy using only the sentiment of the 5th sentences, but you can also experiment with running sentiment analysis on the context sentences as well to see if you can improve upon this.*

# %%
# Computes an accuracy given the data dictionary and a list of [0, 1] predictions.

def compute_accuracy(data, predictions):
  ground_truth = np.array([ex['label'] for ex in data])
  predictions = np.array(predictions)
  assert len(ground_truth) == len(predictions)

  return np.sum(np.equal(ground_truth, predictions)) / float(len(ground_truth))

# %%
from random import choice
from textblob import TextBlob

def predict_based_on_sentiment(data):
  """Returns a list with one value per example in data.

  List values should either be 0 or 1 indicating which ending is predicted.
  """
  predictions = list()

  for datum in data:
    context = datum["context"]
    options = datum["options"]

    average_context_polarity = sum([TextBlob(text).sentiment.polarity for text in options]) / 4
    # todo: use averaged context polarity to make prediction

    sentiment1 = TextBlob(options[0]).sentiment.polarity
    sentiment2 = TextBlob(options[1]).sentiment.polarity

    if sentiment1 > sentiment2:
      predictions.append(0)
    elif sentiment1 < sentiment2:
      predictions.append(1)
    else:
      predictions.append(choice([0, 1]))

  return predictions

predictions_valid_2016 = predict_based_on_sentiment(valid_2016_data)
print('\n2016 validation accuracy: ' )
print(compute_accuracy(valid_2016_data, predictions_valid_2016))

predictions_valid_2018 = predict_based_on_sentiment(valid_2018_data)
print('\n2018 validation accuracy: ' )
print(compute_accuracy(valid_2018_data, predictions_valid_2018))

predictions_test_2016 = predict_based_on_sentiment(test_2016_data)
print('\n2016 test accuracy: ' )
print(compute_accuracy(test_2016_data, predictions_test_2016))
# Out:
# 2016 validation accuracy:
# nan
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in true_divide
#   import sys
# 2018 validation accuracy:
# 0.5747931253978358
#
# 2016 test accuracy:
# 0.5611972207375735

# %% [markdown]
# # Now using context sentences

# %%
from random import choice
from textblob import TextBlob

def predict_based_on_sentiment(data):
  """Returns a list with one value per example in data.

  List values should either be 0 or 1 indicating which ending is predicted.
  """
  predictions = list()

  for datum in data:
    context = datum["context"]
    options = datum["options"]

    average_context_polarity = sum([TextBlob(text).sentiment.polarity for text in options]) / 4
    # todo: use averaged context polarity to make prediction

    sentiment1 = TextBlob(options[0]).sentiment.polarity
    sentiment2 = TextBlob(options[1]).sentiment.polarity

    delta1 = abs(sentiment1 - average_context_polarity)
    delta2 = abs(sentiment2 - average_context_polarity)

    if sentiment1 - sentiment2 > .1:
      predictions.append(0)
    elif sentiment2 - sentiment1 > .1:
      predictions.append(1)
    elif delta1 > delta2:
      predictions.append(0)
    else:
      predictions.append(1)

    print("Context " + str(context))
    print("Prediction " +  options[predictions[-1]])
    print("Option 0 " +  options[0])
    print("Option 1 " +  options[1])
    print("Sentiment of 0 " + str(sentiment1))
    print("Sentiment of 1 " + str(sentiment2))
    print("Average context sentiment " + str(average_context_polarity))

  return predictions

predictions_valid_2016 = predict_based_on_sentiment(valid_2016_data)
print('\n2016 validation accuracy: ' )
print(compute_accuracy(valid_2016_data, predictions_valid_2016))

predictions_valid_2018 = predict_based_on_sentiment(valid_2018_data)
print('\n2018 validation accuracy: ' )
print(compute_accuracy(valid_2018_data, predictions_valid_2018))

predictions_test_2016 = predict_based_on_sentiment(test_2016_data)
print('\n2016 test accuracy: ' )
print(compute_accuracy(test_2016_data, predictions_test_2016))
# Out:
# 2016 validation accuracy:
# nan
# Context ['Rick grew up in a troubled household.', 'He never found good support in family, and turned to gangs.', "It wasn't long before Rick got shot in a robbery.", 'The incident caused him to turn a new leaf.']
# Prediction He is happy now.
# Option 0 He is happy now.
# Option 1 He joined a gang.
# Sentiment of 0 0.8
# Sentiment of 1 0.0
# Average context sentiment 0.2
# Context ["Laverne needs to prepare something for her friend's party.", 'She decides to bake a batch of brownies.', 'She chooses a recipe and follows it closely.', 'Laverne tests one of the brownies to make sure it is delicious.']
# Prediction The brownies are so delicious Laverne eats two of them.
# Option 0 The brownies are so delicious Laverne eats two of them.
# Option 1 Laverne doesn't go to her friend's party.
# Sentiment of 0 1.0
# Sentiment of 1 0.0
# Average context sentiment 0.25
# Context ['Sarah had been dreaming of visiting Europe for years.', 'She had finally saved enough for the trip.', 'She landed in Spain and traveled east across the continent.', "She didn't like how different everything was."]
# Prediction Sarah decided that she preferred her home over Europe.
# Option 0 Sarah then decided to move to Europe.
# Option 1 Sarah decided that she preferred her home over Europe.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Gina was worried the cookie dough in the tube would be gross.', 'She was very happy to find she was wrong.', 'The cookies from the tube were as good as from scratch.', 'Gina intended to only eat 2 cookies and save the rest.']
# Prediction Gina liked the cookies so much she ate them all in one sitting.
# Option 0 Gina liked the cookies so much she ate them all in one sitting.
# Option 1 Gina gave the cookies away at her church.
# Sentiment of 0 0.4
# Sentiment of 1 0.0
# Average context sentiment 0.1
# Context ['It was  my final performance in marching band.', 'I was playing the snare drum in the band.', 'We played Thriller and Radar Love.', 'The performance was flawless.']
# Prediction I was very proud of my performance.
# Option 0 I was very proud of my performance.
# Option 1 I was very ashamed of my performance.
# Sentiment of 0 1.0
# Sentiment of 1 0.2
# Average context sentiment 0.3
# Context ['Jim found an old disposable camera in the bottom of his junk drawer.', 'He began snapping away at everything around him.', 'The counter clicked down to one final photo.', 'The gravity of the situation began to dawn on Jim.']
# Prediction Jim took 20 more photos.
# Option 0 Jim took time to decide what he would take a picture of.
# Option 1 Jim took 20 more photos.
# Sentiment of 0 0.0
# Sentiment of 1 0.5
# Average context sentiment 0.125
# Context ['Ron started his new job as a landscaper today.', 'He loves the outdoors and has always enjoyed working in it.', "His boss tells him to re-sod the front yard of the mayor's home.", 'Ron is ecstatic, but does a thorough job and finishes super early.']
# Prediction His boss commends him for a job well done.
# Option 0 Ron is immediately fired for insubordination.
# Option 1 His boss commends him for a job well done.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['John and Billy became very skilled at beer pong.', 'They entered a contest in college.', 'They won the contest and advanced to the next level.', 'The next level sent them to Vegas.']
# Prediction In Vegas, John and Billy competed against eighty contestants.
# Option 0 In Vegas, John and Billy competed against eighty contestants.
# Option 1 John and Billy were disappointed.
# Sentiment of 0 0.0
# Sentiment of 1 -0.75
# Average context sentiment -0.1875
# Context ['Caroline was a student in medical school.', 'Caroline worked very hard to get good grades.', 'One day Caroline failed a test by one point.', 'Caroline was very frustrated but she continued to study hard.']
# Prediction Later, she passed the test.
# Option 0 But she gave up.
# Option 1 Later, she passed the test.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Trish hated the outdoors.', 'Her friends convinced her to go camping.', "She wasn't having a good time.", 'They showed her how to fish and showed her the stars.']
# Prediction The fish had very interesting mating habits.
# Option 0 Eventually Trish grudgingly came to accept nature.
# Option 1 The fish had very interesting mating habits.
# Sentiment of 0 -0.6
# Sentiment of 1 0.65
# Average context sentiment 0.012500000000000011
# Context ['Tony was happy to be going on his first cruise.', 'He arrived at the docks and was ready with all his luggage.', "When he walked around the corner he couldn't believe the size of it.", 'He boarded and the ship left the docks.']
# Prediction Tony enjoyed going on the cruise.
# Option 0 Tony enjoyed going on the cruise.
# Option 1 Tony was scared of the ocean.
# Sentiment of 0 0.5
# Sentiment of 1 0.0
# Average context sentiment 0.125
# Context ['Ignacio wants to play a sport while he is in college.', 'Since he was a good swimmer, he decides to try out for swim the team.', 'Ignacio makes it onto the team easily.', 'At the first swim meet, Ignacio wins second place!']
# Prediction Ignacio won a silver medal.
# Option 0 Ignacio gave up swimming.
# Option 1 Ignacio won a silver medal.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Danny bought a boat.', 'His nearby marina was having a race.', 'He decided to enter.', 'Danny and his best friend manned the boat.']
# Prediction They prepared for the start of the race.
# Option 0 Danny decided to go to sleep.
# Option 1 They prepared for the start of the race.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['At school, Mary received an assignment to write an essay about pandas.', 'Luckily, Mary loved pandas, as was excited to get started.', 'As soon as she got home, Mary booted up her computer and began.', 'She wrote about all she knew and researched a little too!']
# Prediction Mary couldn't wait to present her report.
# Option 0 Mary disliked Pandas.
# Option 1 Mary couldn't wait to present her report.
# Sentiment of 0 -0.2
# Sentiment of 1 0.0
# Average context sentiment -0.05
# Context ['Ellen dreamed of winning a prize for her roses.', 'She planned to enter her special purple rose at the fair.', 'She fertilized the rose bush and covered it each night.', 'The roses grew more beautiful every day.']
# Prediction Ellen ended up winning the prize.
# Option 0 Ellen ended up winning the prize.
# Option 1 Ellen had to pay a replacement fee for her library card.
# Sentiment of 0 0.5
# Sentiment of 1 0.0
# Average context sentiment 0.125
# Context ['Jesse had just started fifth grade.', "He tried to make friends with the other boys, but he couldn't.", 'He decided to make friends with the girls instead.', 'They girls welcomed him into their social groups happily.']
# Prediction Jesse went to the park with his new friend, Roger.
# Option 0 Jesse went to the park with his new friend, Roger.
# Option 1 Jesse was picked on by the other boys in school.
# Sentiment of 0 0.13636363636363635
# Sentiment of 1 -0.125
# Average context sentiment 0.0028409090909090884
# Context ['Tiffany was getting overwhelmed at work.', 'While she liked her job, she longed for a break.', 'One day, she tripped outside on uneven pavement.', 'She broke her ankle and had to be off work for a couple months.']
# Prediction She was in pain but happy to not have to go to work.
# Option 0 Tiffany went in to work the next day.
# Option 1 She was in pain but happy to not have to go to work.
# Sentiment of 0 0.0
# Sentiment of 1 0.8
# Average context sentiment 0.2
# Context ['Gina misplaced her phone at her grandparents.', "It wasn't in the living room.", 'She had been in the car before napping in the living room.', "She grabbed her dad's keys and ran outside."]
# Prediction She found her phone in the car.
# Option 0 But she didn't want her phone anymore.
# Option 1 She found her phone in the car.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Alice was getting married in a few weeks.', 'One night, her mother called and she forgot to call her back.', 'Her mother left an angry message on her phone.', 'She threatened not to come to the wedding.']
# Prediction Alice messaged a cute guy she saw on Tinder.
# Option 0 Alice called her mother and apologized profusely.
# Option 1 Alice messaged a cute guy she saw on Tinder.
# Sentiment of 0 0.0
# Sentiment of 1 0.5
# Average context sentiment 0.125
# Context ['Ted loves to go to the movies.', 'He sees almost everyone and votes at the Oscars.', 'He has a big party for the Oscars and they all place bets.', 'Ted almost always wins with the movies he chooses.']
# Prediction He decides to stop watching movies.
# Option 0 Ted continues to watch several movies a week.
# Option 1 He decides to stop watching movies.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Nya had been asked on a paintball trip with friends.', 'She was nervous about going.', 'But she went anyways, hoping to have fun.', 'She shot paintballs at her friends and laughed the whole time.']
# Prediction She loved it so much she planned a trip for the next week.
# Option 0 She loved it so much she planned a trip for the next week.
# Option 1 She was shot and vowed to never go there again.
# Sentiment of 0 0.3
# Sentiment of 1 0.0
# Average context sentiment 0.075
# Context ["All of Javier's friends at school have smartphones.", 'However, he still uses an old style flip phone.', 'One day he decides to buy a smartphone too.', 'At first he loves having the access to internet everywhere he goes.']
# Prediction But then he misses his old phone.
# Option 0 Javier decides to get a smartphone.
# Option 1 But then he misses his old phone.
# Sentiment of 0 0.0
# Sentiment of 1 0.1
# Average context sentiment 0.025
# Context ['Rachel decided to donate blood at the local blood drive.', 'She was a little nervous because this was her first time.', 'The next day Rachel received a call from the doctor that she saw.', 'The doctor told her that he had bad news.']
# Prediction Rachel started moonwalking with excitement.
# Option 0 Rachel broke down in tears.
# Option 1 Rachel started moonwalking with excitement.
# Sentiment of 0 -0.15555555555555559
# Sentiment of 1 0.0
# Average context sentiment -0.038888888888888896
# Context ['Ron was watching a high-speed chase on TV.', 'The cop was chasing the bad guy through his neighborhood.', 'It was terrifying!', 'But then the cop caught the bad guy.']
# Prediction Ron applauded the officer's performance.
# Option 0 Ron started collecting bottle caps.
# Option 1 Ron applauded the officer's performance.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Sam loved his old belt.', 'He matched it with everything.', 'Unfortunately he gained too much weight.', 'It became too small.']
# Prediction Sam was happy.
# Option 0 Sam went on a diet.
# Option 1 Sam was happy.
# Sentiment of 0 0.0
# Sentiment of 1 0.8
# Average context sentiment 0.2
# Context ['Larry bought a new motorcycle.', 'He was excited to look cool.', 'The first time he tried riding it he dropped it.', 'He hurt his leg and had to go to the hospital.']
# Prediction Larry loved going to the hospital.
# Option 0 Larry loved going to the hospital.
# Option 1 Larry became careful.
# Sentiment of 0 0.7
# Sentiment of 1 -0.1
# Average context sentiment 0.15
# Context ['I went on a blind date a few days ago.', 'She was cute and friendly.', 'We were set up through a co worker.', 'We seem to have some things in common.']
# Prediction We broke up right away.
# Option 0 Soon we were boyfriend and girlfriend and thinking of marriage.
# Option 1 We broke up right away.
# Sentiment of 0 0.0
# Sentiment of 1 0.2857142857142857
# Average context sentiment 0.07142857142857142
# Context ["Sammy's coffee grinder was broken.", 'He needed something to crush up his coffee beans.', 'He put his coffee beans in a plastic bag.', 'He tried crushing them with a hammer.']
# Prediction It worked for Sammy.
# Option 0 Sammy was not that into coffee.
# Option 1 It worked for Sammy.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Last week Jared was driving to work.', 'He had been partying hard the night before.', "He didn't get any sleep.", 'Before he knew it his car was facing oncoming traffic.']
# Prediction Jared swerved quickly and managed to avoid a collision.
# Option 0 Jared swerved quickly and managed to avoid a collision.
# Option 1 Jared decided to accelerate.
# Sentiment of 0 0.3333333333333333
# Sentiment of 1 0.0
# Average context sentiment 0.08333333333333333
# Context ['Joe grew a big batch of peas in his garden.', 'He brought the peas inside and shelled them all.', 'Then he cooked them up in a big pot.', 'He added ham, bacon, and carrots to make thick pea soup.']
# Prediction Joe thought about working in the garden as he ate the yummy soup.
# Option 0 Joe thought about working in the garden as he ate the yummy soup.
# Option 1 Joe dumped the pot outside because he hated soup.
# Sentiment of 0 0.0
# Sentiment of 1 -0.45
# Average context sentiment -0.1125
# Context ['Aliza had a long lost ex-boyfriend she was bound to find.', 'The problem was, he moved to a new state.', 'She decided to use Facebook to find him.', 'She found him, but he was married with kids.']
# Prediction He fell in love with Aliza and they were married.
# Option 0 Aliza was sad, but she never contacted him again.
# Option 1 He fell in love with Aliza and they were married.
# Sentiment of 0 -0.5
# Sentiment of 1 0.375
# Average context sentiment -0.03125
# Context ['Lina went to see how candy canes were made.', 'She watched as the workers added dye to the hot candy.', 'Then, they stretched it out to make it shiny.', 'Finally, they shaped it into a cane and let it cool.']
# Prediction Lina felt a new appreciation for candy canes.
# Option 0 Lina now knew that candy canes were boring.
# Option 1 Lina felt a new appreciation for candy canes.
# Sentiment of 0 -1.0
# Sentiment of 1 0.13636363636363635
# Average context sentiment -0.2159090909090909
# Context ["When I first moved into my house, I didn't know my neighbors.", 'While mowing one day, I found a kickball in my yard.', 'I felt this was the perfect opportunity to meet my neighbors.', 'I grabbed the ball and went next door to return it.']
# Prediction They were very friendly.
# Option 0 They were very friendly.
# Option 1 I threw the kickball through their closed window.
# Sentiment of 0 0.48750000000000004
# Sentiment of 1 -0.1
# Average context sentiment 0.09687500000000002
# Context ['Bev had been studying very hard.', "She couldn't wait for the weekend.", 'When it came, she slept in very late.', 'Then she got up and went out to party.']
# Prediction Bev got the mail and fed the fish, just like she did every day.
# Option 0 By Sunday night, Bev was exhausted again.
# Option 1 Bev got the mail and fed the fish, just like she did every day.
# Sentiment of 0 -0.4
# Sentiment of 1 0.0
# Average context sentiment -0.1
# Context ["We went to Frank Pepe's pizza shop three weeks ago.", 'The chain is quite famous in Connecticut.', 'The chain recently opened in Boston.', 'We went early to beat the crowd.']
# Prediction We had a great pizza at Frank Pepe's pizza shop.
# Option 0 We walked 5 growling dogs at the park across town.
# Option 1 We had a great pizza at Frank Pepe's pizza shop.
# Sentiment of 0 0.0
# Sentiment of 1 0.8
# Average context sentiment 0.2
# Context ['Bernice always wanted to travel to Africa.', 'Bernice decided she would take a trip for her birthday next year.', 'Bernice started to look at the price of airline tickets for the trip.', 'In addition, Bernice looked up the price of hotels as well.']
# Prediction Bernice decided to get an airplane ticket and reserve a room.
# Option 0 Bernice went to Europe for her birthday.
# Option 1 Bernice decided to get an airplane ticket and reserve a room.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Jim made spinach cookies.', 'He sold them for five dollars each.', 'No one bought any.', 'However, at the last minute a man wanted twenty.']
# Prediction He was surprised but thankful.
# Option 0 He was surprised but thankful.
# Option 1 Jim thought he was crazy and left.
# Sentiment of 0 0.1
# Sentiment of 1 -0.3
# Average context sentiment -0.049999999999999996
# Context ["Randy's friend gave him directions to his house.", 'He was supposed to take a right after the white house.', 'Randy continued to get lost.', 'He backtracked continuously until he finally found it.']
# Prediction Randy saw the house but kept on driving and didn't come back.
# Option 0 Randy told his friend how relieved he was he found it.
# Option 1 Randy saw the house but kept on driving and didn't come back.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['I decided to go on a bike ride with my brother.', 'We both headed out in the morning.', 'We were having a lot of fun.', 'Suddenly, he hit a rock and broke his wheel!']
# Prediction Watching my brother crash was fun.
# Option 0 Watching my brother crash was fun.
# Option 1 I felt very badly for my brother.
# Sentiment of 0 0.3
# Sentiment of 1 -0.9099999999999998
# Average context sentiment -0.15249999999999997
# Context ['Anna went to the salon.', 'She was getting her nails done for the first time.', 'She was nervous, but the tech was friendly.', 'He did her nails quickly and expertly.']
# Prediction Anna really liked her new hairstyle.
# Option 0 Anna felt very fashionable when she left the salon.
# Option 1 Anna really liked her new hairstyle.
# Sentiment of 0 0.1
# Sentiment of 1 0.36818181818181817
# Average context sentiment 0.11704545454545454
# Context ['David and Sarah were friends during childhood.', 'When they went to college, each moved to a different town.', 'Sarah received an unexpected call from David on Friday.', 'They had dinner and talked about their lives.']
# Prediction Sarah was glad they were able to catch up.
# Option 0 Sarah was glad they were able to catch up.
# Option 1 Sarah and david went to go get dinner right after that.
# Sentiment of 0 0.5
# Sentiment of 1 0.2857142857142857
# Average context sentiment 0.19642857142857142
# Context ['AJ and his mom were at the grocery store.', 'Aj was looking at a cereal box and when he looked up his mom was gone.', 'He immediately started to feel panic.', 'Then his mom stepped out from behind a display of soup.']
# Prediction AJ let out a sigh of relief.
# Option 0 AJ then began to feel sad.
# Option 1 AJ let out a sigh of relief.
# Sentiment of 0 -0.5
# Sentiment of 1 0.0
# Average context sentiment -0.125
# Context ['Joe went to the junkyard to find treasures.', 'He dug through a stack of old clothes.', 'At the bottom was a vintage shirt with a rock band on it.', 'Joe put the shirt on to try it out.']
# Prediction Joe was happy the shirt fit.
# Option 0 Joe was happy the shirt fit.
# Option 1 Joe hated rock music afterwards.
# Sentiment of 0 0.6000000000000001
# Sentiment of 1 -0.9
# Average context sentiment -0.07499999999999998
# Context ['Priya decided to try a new restaurant.', 'She drove to a new cafe that opened.', 'Priya sat at a booth.', 'She ordered a mimosa and a breakfast burrito.']
# Prediction Priya thought her food was delicious.
# Option 0 Priya thought her food was delicious.
# Option 1 Priya decided not to eat and left.
# Sentiment of 0 1.0
# Sentiment of 1 0.0
# Average context sentiment 0.25
# Context ['Karen was assigned a roommate her first year of college.', 'One day, her roommate asked her to go to a nearby city for a concert.', 'Karen agreed happily.', 'The show was absolutely exhilarating.']
# Prediction Karen became good friends with her roommate.
# Option 0 Karen hated her roommate.
# Option 1 Karen became good friends with her roommate.
# Sentiment of 0 -0.9
# Sentiment of 1 0.7
# Average context sentiment -0.05000000000000002
# Context ['We took a family vacation to the beach last year.', 'I spent a lot of time reading with my mom on the beach.', 'One day while reading, I got stung by a horrible beach wasp.', 'My arm swelled and was painful, I almost had to go to the hospital.']
# Prediction I found I loved being swollen.
# Option 0 Eventually I healed.
# Option 1 I found I loved being swollen.
# Sentiment of 0 0.0
# Sentiment of 1 0.7
# Average context sentiment 0.175
# Context ['Donald was kind of the class clown.', 'He wanted to be class president.', 'So he figured if he acted like an idiot people would vote for him.', 'He would get up and just yell and be foolish.']
# Prediction Donald hoped this foolishness won him the election.
# Option 0 Don hated elections.
# Option 1 Donald hoped this foolishness won him the election.
# Sentiment of 0 -0.9
# Sentiment of 1 0.0
# Average context sentiment -0.225
# Context ["Eddie and Angela hadn't been talking to each other for a long time.", 'They lived in their house together like strangers.', 'Finally, they sat down and agreed, it was time for a divorce.', 'Eddie went to the courthouse and filed the paperwork.']
# Prediction They fell back in love and stayed together forever.
# Option 0 They were divorced a few months later.
# Option 1 They fell back in love and stayed together forever.
# Sentiment of 0 -0.1
# Sentiment of 1 0.25
# Average context sentiment 0.0375
# Context ['Rachel adopted a cat over ten Years ago.', 'Suddenly, the cat was acting more lethargic and losing weight.', 'Concerned, Rachel took her cat to the vet.', 'The vet told Rachel that her cat had developed cancer.']
# Prediction The vet treated her cat's cancer the best they could.
# Option 0 Rachel was excited to hear the news.
# Option 1 The vet treated her cat's cancer the best they could.
# Sentiment of 0 0.375
# Sentiment of 1 1.0
# Average context sentiment 0.34375
# Context ['Jim is a new driver and has never been pulled over before.', 'Yesterday he was pulled over for speeding.', 'The officer explained to him why he was being given a ticket.', 'Jim will have to work overtime to pay for the ticket.']
# Prediction Jim was happy to see the officer.
# Option 0 Jim is very upset.
# Option 1 Jim was happy to see the officer.
# Sentiment of 0 0.2
# Sentiment of 1 0.8
# Average context sentiment 0.25
# Context ['I love avocados.', 'I ate a sandwich covered in them.', 'After I ate it, my mouth was itchy and tingly.', 'I talked to my doctor about it later.']
# Prediction It turned out I was allergic to avocados.
# Option 0 He said I was paranoid, and charged me $100.
# Option 1 It turned out I was allergic to avocados.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['David was an author that had trouble finding inspiration for his work.', 'One day he had a dream of him being in a post apocalyptic world.', 'He thought that this was destiny and began to write his thoughts.', 'Eventually he had hundreds of pages written.']
# Prediction David then uploaded his new video.
# Option 0 David then uploaded his new video.
# Option 1 David then had his manuscript published.
# Sentiment of 0 0.13636363636363635
# Sentiment of 1 0.0
# Average context sentiment 0.03409090909090909
# Context ['Boris was addicted to video games.', 'His mother was concerned.', 'She called a psychologist to get help.', 'The psychologist tried to convince Boris to stop his addiction.']
# Prediction Boris decided to wear the dress.
# Option 0 Boris realized he was wasting his life.
# Option 1 Boris decided to wear the dress.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['A police officer came down with the flu today.', 'He was unable to go into work as he could barely get out of bed.', 'His wife spent time taking care of him and making sure he was okay.', 'He made sure to drink enough and eat enough.']
# Prediction The police officer eventually got better.
# Option 0 The police officer had to give up his badge and gun.
# Option 1 The police officer eventually got better.
# Sentiment of 0 0.0
# Sentiment of 1 0.5
# Average context sentiment 0.125
# Context ['My friend nathan and his family went to the lake one summer.', "One day Nathan's dad left and didn't leave a lighter for his mom.", 'Well his mom was very upset and made him walk to the store barefoot.', 'Poor Nathan had to walk down a gravel road to bring his mom matches.']
# Prediction When Nathan returned, he felt very happy for the exercise.
# Option 0 When Nathan returned, he felt very happy for the exercise.
# Option 1 When Nathan returned, his mom apologized for being so mean.
# Sentiment of 0 1.0
# Sentiment of 1 -0.3125
# Average context sentiment 0.171875
# Context ['Gary was a brave child.', 'One day he decided to climb over the fence in his backyard.', 'His parents looked all over for him.', 'They found him sitting on the swing at the park.']
# Prediction Gary's parents were relieved to find him.
# Option 0 Gary's parents were relieved to find him.
# Option 1 Gary's parents were disappointed to find him.
# Sentiment of 0 0.0
# Sentiment of 1 -0.75
# Average context sentiment -0.1875
# Context ['Timmy was caught with unpaid parking tickets.', "He didn't have enough money to pay for them.", 'Instead he had to be arrested and jailed for two days.', 'He lost his jobs for missing work.']
# Prediction Timmy was promoted for working so much all the time.
# Option 0 Timmy was promoted for working so much all the time.
# Option 1 Timmy then had to find another job,
# Sentiment of 0 0.2
# Sentiment of 1 0.0
# Average context sentiment 0.05
# Context ['When I was younger, I went to summer camp.', 'We had a lot of fun playing games with the counselors.', 'My favorite thing to do was play cards.', 'The camp counselors knew so many different card games.']
# Prediction My time with the minister was very useful.
# Option 0 My time with the minister was very useful.
# Option 1 My favorite card game was poker.
# Sentiment of 0 0.39
# Sentiment of 1 0.04999999999999999
# Average context sentiment 0.11
# Context ['Amber had a lot of things to do this Sunday.', 'She made a list of all the places she needed to go.', 'She hurried to get ready.', 'She was worried that she would not have enough time.']
# Prediction Amber enjoyed a relaxing two hour brunch.
# Option 0 Amber enjoyed a relaxing two hour brunch.
# Option 1 Amber was so hurried she left the list at home.
# Sentiment of 0 0.5
# Sentiment of 1 0.0
# Average context sentiment 0.125
# Context ['Eve needed a new couch in her parlor.', 'But she could not afford to buy one!', 'Then she went to a secondhand store and found a great one.', 'She had it delivered and set up in her living room.']
# Prediction Eve thought the couch was very comfortable.
# Option 0 She bought a new couch to replace it.
# Option 1 Eve thought the couch was very comfortable.
# Sentiment of 0 0.13636363636363635
# Sentiment of 1 0.52
# Average context sentiment 0.1640909090909091
# Context ['Jason was terrified of spiders.', 'He went to a therapist and discussed his fear.', 'His therapist said he should confront his fear to overcome it.', "Jason's homework was to look for a spider in his basement."]
# Prediction He found a very large spider there.
# Option 0 He found a very large spider there.
# Option 1 Jason took a hot shower.
# Sentiment of 0 0.2785714285714286
# Sentiment of 1 0.25
# Average context sentiment 0.13214285714285715
# Context ['Linda began to have problems with a coworker at her job.', 'The coworker had started bossing her around at work.', 'The coworker even talked behind her back.', 'Linda went to her boss with the issue and the boss mediated them.']
# Prediction Linda and the coworker ended up being best friends.
# Option 0 Her boss fired her the next day.
# Option 1 Linda and the coworker ended up being best friends.
# Sentiment of 0 0.0
# Sentiment of 1 1.0
# Average context sentiment 0.25
# Context ['Sara wanted her kids to have a great Christmas.', 'She saved all year and started her shopping in November.', 'She shopped deals and spent all her savings.', 'She spent two days wrapping dozens of presents.']
# Prediction She returned all of the presents for cheaper ones.
# Option 0 All of the presents were wrapped and stored for the holidays.
# Option 1 She returned all of the presents for cheaper ones.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Megan has been struggling with a drug habit for years.', 'She hit rock bottom when she lost her family and kids.', 'Her distant family decided to stage an intervention.', 'After the event, she got into a rehab facility.']
# Prediction She was able to get off drugs after some time.
# Option 0 She was able to get off drugs after some time.
# Option 1 When she arrived, she did drugs all day.
# Sentiment of 0 0.5
# Sentiment of 1 0.0
# Average context sentiment 0.125
# Context ['Tyler has been unemployed for Years.', 'He has spent the last few months diligently applying for work.', 'However, all of his applications are rejected.', "The rejections contribute to Tyler's feelings of desperation."]
# Prediction He is thrilled about his new responsibilities at work.
# Option 0 He is thrilled about his new responsibilities at work.
# Option 1 He realizes he might have to apply for public assistance.
# Sentiment of 0 0.36818181818181817
# Sentiment of 1 0.0
# Average context sentiment 0.09204545454545454
# Context ['Bobby was having a birthday party.', 'His friends bought him a huge cake.', 'A woman jumped out of the cake.', 'Bobby was surprised and amused.']
# Prediction Bobby had a good party.
# Option 0 Bobby had a good party.
# Option 1 Bobby was mad at his friends.
# Sentiment of 0 0.7
# Sentiment of 1 -0.625
# Average context sentiment 0.01874999999999999
# Context ['It was the last day of our vacation.', 'We were eating lunch on the patio of the hotel.', 'We laughed and smiled because it was a great vacation.', 'Then we packed our bags and drove to the airport.']
# Prediction We all vowed to never go back again.
# Option 0 We want to revisit someday.
# Option 1 We all vowed to never go back again.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Mother asked the children to help fold laundry.', 'The children took the clean clothes into the living room.', 'They dumped the clothes on the floor.', 'They folded the clothes neatly into piles.']
# Prediction They then put their clothes up neatly.
# Option 0 The clothes were filthy and unfolded.
# Option 1 They then put their clothes up neatly.
# Sentiment of 0 -0.8
# Sentiment of 1 0.0
# Average context sentiment -0.2
# Context ['Timmy loves watching cartoons.', "His parents don't let him watch unless he does his chores.", "Today's chore is to clean his room.", "Timmy's room is a mess."]
# Prediction Timmy went to the mess hall for breakfast.
# Option 0 Timmy went to the mess hall for breakfast.
# Option 1 Timmy spent all day cleaning so he could watch tv.
# Sentiment of 0 -0.175
# Sentiment of 1 -0.1
# Average context sentiment -0.06875
# Context ['My daughter had her baby shower in our Boston home.', 'She invited friends and family in the area.', 'Her old college roommate lives in Hawaii.', 'She decided to surprise my daughter by flying 4800 miles.']
# Prediction My daughter was excited.
# Option 0 My daughter was disappointed.
# Option 1 My daughter was excited.
# Sentiment of 0 -0.75
# Sentiment of 1 0.375
# Average context sentiment -0.09375
# Context ["Pam's house was where the party was.", 'Everyone bought gifts.', 'Pam bought a cake.', 'Everyone danced and had fun!']
# Prediction Pam was a good hostess.
# Option 0 Pam was a lousy hostess.
# Option 1 Pam was a good hostess.
# Sentiment of 0 -0.5
# Sentiment of 1 0.7
# Average context sentiment 0.04999999999999999
# Context ['Ellen always hated school.', 'The kids made fun of her every day.', 'They called her smelly Elly.', 'She decided to start taking baths.']
# Prediction Ellen liked the negative attention.
# Option 0 Ellen liked the negative attention.
# Option 1 Ellen was appalled.
# Sentiment of 0 0.15
# Sentiment of 1 -0.8
# Average context sentiment -0.1625
# Context ['Jim got his first credit card in college.', "He didn't have a job so he bought everything on his card.", 'After he graduated he amounted a $10,000 debt.', 'Jim realized that he was foolish to spend so much money.']
# Prediction Jim decided to open another credit card.
# Option 0 Jim decided to devise a plan for repayment.
# Option 1 Jim decided to open another credit card.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Tim was entering a baking contest.', 'He decided to make his famous donuts.', 'He made a big batch and entered them into the contest.', 'The judges thought they were delicious.']
# Prediction Tim won the baking contest.
# Option 0 The judges vomited from the taste of the donuts.
# Option 1 Tim won the baking contest.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['My two year old son refused to wear training pants.', 'He always begged to wear a diaper.', 'One day, out of frustration, I let him remain naked.', "He went to the potty and used it when I wasn't looking."]
# Prediction Child protection services removed him from the home.
# Option 0 Now I don't try to make him wear training pants.
# Option 1 Child protection services removed him from the home.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Holly was glad to be safely inside her house as the storm raged.', 'She was watching the storm as she heard a loud crack.', 'Lightning had hit a tree beside the house.', 'She stared as she watched it fall.']
# Prediction She went outside to fly a kite.
# Option 0 She went outside to fly a kite.
# Option 1 She was relieved that it didn't hit anything.
# Sentiment of 0 0.4
# Sentiment of 1 0.0
# Average context sentiment 0.1
# Context ['Jill saw an infomercial for unbreakable glass cups.', 'She was amazed and ordered them.', 'When Jill received the cups, she wanted to test them.', 'She dropped one on her hardwood floor.']
# Prediction The cloth ripped in two, much to Jill's surprise.
# Option 0 It broke and Jill felt dumb for believing the hype.
# Option 1 The cloth ripped in two, much to Jill's surprise.
# Sentiment of 0 -0.375
# Sentiment of 1 0.2
# Average context sentiment -0.04375
# Context ['Addie was working at the mall at Hollister when a strange man came in.', 'Before she knew it, Addie looked behind her and saw stolen clothes.', 'Addie got scared and tried to chase the man out.', 'Luckily guards came and arrested him.']
# Prediction Addie was relieved and took deep breaths to calm herself.
# Option 0 Addie was put in jail for her crime.
# Option 1 Addie was relieved and took deep breaths to calm herself.
# Sentiment of 0 -0.1
# Sentiment of 1 0.15000000000000002
# Average context sentiment 0.012500000000000004
# Context ['Sean was going for a job interview.', 'He arrived at the business and asked for the manager.', 'The manager took him to the back and interviewed him.', 'Then, the manager showed him around and explained the job.']
# Prediction The manager wanted Sean to understand everything.
# Option 0 The manager hoped Sean would perform badly.
# Option 1 The manager wanted Sean to understand everything.
# Sentiment of 0 -0.6999999999999998
# Sentiment of 1 0.0
# Average context sentiment -0.17499999999999996
# Context ['Fred made a bet with Sam over who could lose more weight in a month.', 'Fred really wanted to win the bet, which was for $100.', 'Fred worked out daily, avoided fast food, and skipped dinner.', 'At the end of the month Fred was feeling confident he would win.']
# Prediction Fred ended up winning the bet, and the $100.
# Option 0 Fred cancelled the bet at the end of the month.
# Option 1 Fred ended up winning the bet, and the $100.
# Sentiment of 0 0.0
# Sentiment of 1 0.5
# Average context sentiment 0.125
# Context ['John went skydiving for the first time.', 'He went with an instructor on a plane into the air.', 'He screamed when they jumped.', 'John was terribly afraid of heights and passed out.']
# Prediction John loved every second of the skydiving trip.
# Option 0 John loved every second of the skydiving trip.
# Option 1 When he woke up, he had already landed.
# Sentiment of 0 0.35
# Sentiment of 1 0.0
# Average context sentiment 0.0875
# Context ['Gina and her family were leaving the park.', 'They had been there all afternoon.', "Now they were going to her aunt's house.", "Gina begged to be dropped off at her grandma's"]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in true_divide
#   import sys
# Streaming output truncated to the last 5000 lines.
# Option 0 Patty had a great time with her friends.
# Option 1 Patty decided to take everyone out to a restaurant.
# Sentiment of 0 0.8
# Sentiment of 1 0.0
# Average context sentiment 0.2
# Context ['Erica had a coupon for a dozen doughnuts.', 'Erica decided to take them to work.', "Erica's coworkers were surprised that she brought doughnuts.", 'The co workers thanked Erica for her kindness.']
# Prediction Erica was happy to help her co workers.
# Option 0 Erica felt bad for what she had done.
# Option 1 Erica was happy to help her co workers.
# Sentiment of 0 -0.6999999999999998
# Sentiment of 1 0.8
# Average context sentiment 0.02500000000000005
# Context ['Maya was afraid that she was too old to have a family.', 'She dreamed of meeting the perfect man and having kids.', 'Finally she joined a dating service to try to meet the right man.', 'She met a great guy who eventually asked her to marry him.']
# Prediction Maya decided to never get married.
# Option 0 Maya said yes.
# Option 1 Maya decided to never get married.
# Sentiment of 0 0.0
# Sentiment of 1 0.25
# Average context sentiment 0.0625
# Context ['Angelina wants to make an apple pie.', 'She has the apples but they need to be peeled.', 'She starts peeling.', 'Finally they are all peeled.']
# Prediction Angelina is finally ready to make a chocolate cake.
# Option 0 Angelina finishes making the apple pie.
# Option 1 Angelina is finally ready to make a chocolate cake.
# Sentiment of 0 0.0
# Sentiment of 1 0.2
# Average context sentiment 0.05
# Context ['Ana was walking home from school one afternoon.', 'She was texting on her phone as she walked.', 'Not paying attention, And walked right into a telephone pole!', 'She split her lip open quite badly.']
# Prediction Ana also got splinters in her lips!
# Option 0 Ana went to get a metal stud piercing for her lip.
# Option 1 Ana also got splinters in her lips!
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Amy was moving to her new apartment.', 'She took weeks to pack up her things in her apartment.', 'When moving day came her brother said he could no longer help her move.', 'Amy called a moving company to move her things.']
# Prediction Amy was pleased with the moving company.
# Option 0 Amy was pleased with the moving company.
# Option 1 The moving company sold her furniture on eBay.
# Sentiment of 0 0.5
# Sentiment of 1 0.0
# Average context sentiment 0.125
# Context ['Casey owned a private beach.', 'People always wanted to come lay in the sun there.', 'Casey had a marvelous idea to charge people to enter.', 'He made thousands from tourists willing to pay for access!']
# Prediction He sold his private beach due to a lack of profit.
# Option 0 He sold his private beach due to a lack of profit.
# Option 1 He purchased another private beach.
# Sentiment of 0 -0.0625
# Sentiment of 1 0.0
# Average context sentiment -0.015625
# Context ["Eric hired a clown to entertain guests for his son's birthday party.", 'The clown arrived 20 minutes late to the party.', "The clown's stunts were really mundane.", 'The guests were not entertained whatsoever.']
# Prediction Eric told all his friends they should hire the clown.
# Option 0 Eric told all his friends they should hire the clown.
# Option 1 Eric wrote a bad review on the clown online.
# Sentiment of 0 0.0
# Sentiment of 1 -0.6999999999999998
# Average context sentiment -0.17499999999999996
# Context ['Kelsey was due to get a new phone.', 'She did a lot of research and selected the perfect one for her.', 'She went to the store and bought it.', 'Unfortunately, she immediately dropped the phone.']
# Prediction Kelsey didn't care and kept walking.
# Option 0 Kelsey was upset to find that her phone broke.
# Option 1 Kelsey didn't care and kept walking.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Sally went to the blueberry patch with her basket.', 'Sally walked through the rows of blueberry bushes.', 'She picked blueberries until her basket was full.', 'She ate some of the fresh berries as she picked.']
# Prediction Sally loved blueberries.
# Option 0 Sally hated blueberries.
# Option 1 Sally loved blueberries.
# Sentiment of 0 -0.9
# Sentiment of 1 0.7
# Average context sentiment -0.05000000000000002
# Context ['We went on Tower of Terror while at Disney.', 'My wife decided to go on even though she hates rides.', 'She was so nervous the whole time in line.', 'Once we got on the ride the panic started.']
# Prediction She was so scared that she screamed during the whole ride.
# Option 0 She was so scared that she screamed during the whole ride.
# Option 1 She was relaxed and laid back while on the ride.
# Sentiment of 0 0.2
# Sentiment of 1 0.0
# Average context sentiment 0.05
# Context ['Neil took a chartered drive up to Broome, Australia.', 'He used it as a launching point for the Outback.', 'He hired a guide to take him on an Outback tour.', 'Its emptiness and glory silenced him.']
# Prediction Neil had a new appreciation for the Outback.
# Option 0 Neil had a new appreciation for the Outback.
# Option 1 Neil hated the tour.
# Sentiment of 0 0.13636363636363635
# Sentiment of 1 -0.9
# Average context sentiment -0.19090909090909092
# Context ['We moved to Cambridge in 2013.', 'Our cat came to the new place first.', 'She was unfamiliar with the new home.', 'She hid in the kitchen cabinet for hours as we moved.']
# Prediction We were finally able to coax the cat out with treats.
# Option 0 We were finally able to coax the cat out with treats.
# Option 1 The cat loved wondering the new home.
# Sentiment of 0 0.5
# Sentiment of 1 0.41818181818181815
# Average context sentiment 0.22954545454545455
# Context ['Pat liked to spend time online.', 'He downloaded many files without being careful.', 'One day, his computer stopped working.', 'Pat brought it to a computer technician, who told him he had a virus.']
# Prediction The technician installed more viruses on his computer.
# Option 0 The technician installed more viruses on his computer.
# Option 1 Pat asked the technician to remove the virus.
# Sentiment of 0 0.5
# Sentiment of 1 0.0
# Average context sentiment 0.125
# Context ['Bill used to always love going to Cape Cod.', 'He loved being by the ocean.', 'But he also loved all the fresh fish.', 'He would always go to same restaurant.']
# Prediction He liked to order the "Catch of the Day."
# Option 0 He liked to order the "Catch of the Day."
# Option 1 The chef there was notorious for serving spoiled fish.
# Sentiment of 0 0.6
# Sentiment of 1 0.0
# Average context sentiment 0.15
# Context ['Alice was pregnant.', "She went to the doctor's.", 'They scanned her stomach with the ultrasound.', 'Then they told her the sex of her baby.']
# Prediction She decided on the name "Pat" for her new baby.
# Option 0 Alice didn't know to give her baby a boy or girl name.
# Option 1 She decided on the name "Pat" for her new baby.
# Sentiment of 0 0.0
# Sentiment of 1 0.13636363636363635
# Average context sentiment 0.03409090909090909
# Context ['I was on a cruise.', 'We went to Haiti.', 'I did not wear enough sunscreen.', 'I got a horrible sunburn.']
# Prediction The tanning booth was great.
# Option 0 I swore to always wear sunscreen in the future.
# Option 1 The tanning booth was great.
# Sentiment of 0 0.0
# Sentiment of 1 0.8
# Average context sentiment 0.2
# Context ['Pat was playing a pick up soccer game.', 'The other boys were playing rougher than he was used to.', 'One boy slide tackled Pat as he was going in for a goal.', 'Pat landed on his wrist and felt a snap.']
# Prediction Pat's wrist had never felt better.
# Option 0 Pat had to go to the hospital.
# Option 1 Pat's wrist had never felt better.
# Sentiment of 0 0.0
# Sentiment of 1 0.5
# Average context sentiment 0.125
# Context ['The awards ceremony began.', 'The manager announced the awards for all of his employees.', 'Everyone believed that Jane would receive the most outstanding award.', 'However, the manager gave the award to Hannah.']
# Prediction Jane had never been more proud.
# Option 0 Jane had never been more proud.
# Option 1 Jane was crushed.
# Sentiment of 0 0.65
# Sentiment of 1 -0.1
# Average context sentiment 0.1375
# Context ['Joe was at home enjoying an adult beverage.', 'Suddenly a loud crashing sound came from the back yard.', 'Joe rushed out to discover a tree had fallen.', 'He put away the drink.']
# Prediction Joe took a nap on the tree.
# Option 0 Joe went to inspect the damage.
# Option 1 Joe took a nap on the tree.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['It was Christmas morning.', 'Amy was opening her gifts hurriedly, looking for the special one.', 'Then she saw the last box in the corner.', 'She quickly ripped off the wrapping paper.']
# Prediction She calmly walked to school in the rain.
# Option 0 She calmly walked to school in the rain.
# Option 1 It was a the new doll she asked her mother for.
# Sentiment of 0 0.30000000000000004
# Sentiment of 1 0.13636363636363635
# Average context sentiment 0.1090909090909091
# Context ["Ana's family was all visiting her house for Christmas.", 'Suddenly a snow storm rose up and the weather grew bad.', 'Two feet of snow fell!', "Ana's family was all snowed in at her house."]
# Prediction They had a happy, but cramped holiday.
# Option 0 They had a happy, but cramped holiday.
# Option 1 Ana walked to work because the weather was so lovely.
# Sentiment of 0 0.8
# Sentiment of 1 0.5
# Average context sentiment 0.325
# Context ['I had a really good air conditioner.', 'I never cleaned the filter.', 'One day, it stopped working.', 'I got really hot.']
# Prediction I put the filter in the drawer with the vacuum cleaner bags.
# Option 0 I put the filter in the drawer with the vacuum cleaner bags.
# Option 1 I regretted having not cleaned the filter.
# Sentiment of 0 -0.008333333333333333
# Sentiment of 1 0.0
# Average context sentiment -0.0020833333333333333
# Context ['Lily was at the nearby mall with friends when she saw Nick Jonas.', "She was immediately shocked and couldn't believe it.", 'Nick smiled at her and gave her an autograph.', 'Lily was elated.']
# Prediction Lily posted what had happened to all the social media sites.
# Option 0 Lily wiped her nose with the autograph.
# Option 1 Lily posted what had happened to all the social media sites.
# Sentiment of 0 0.0
# Sentiment of 1 0.03333333333333333
# Average context sentiment 0.008333333333333333
# Context ['My son has always been very bright.', 'However, he is not very good at doing his homework.', 'Last trimester, he almost failed three of his classes.', "He had to work very hard to get his grades back up by term's end."]
# Prediction He was a great student all the time.
# Option 0 But after working hard, he managed to pass.
# Option 1 He was a great student all the time.
# Sentiment of 0 -0.2916666666666667
# Sentiment of 1 0.8
# Average context sentiment 0.12708333333333333
# Context ['I got bullied in school because of my teeth.', 'I cried home to my mom, and she called the dentist.', "I soon got braces, and kept them for 4 Year's.", 'After I removed them, everyone told me I was beautiful.']
# Prediction I was glad that I got braces.
# Option 0 I was glad that I got braces.
# Option 1 I realized that I made a huge mistake.
# Sentiment of 0 0.5
# Sentiment of 1 0.4000000000000001
# Average context sentiment 0.22500000000000003
# Context ['Alice was a dog trainer.', "She never came across a dog she couldn't help.", 'One day, a man brought a dog named Henry to Alice.', 'Henry was very withdrawn due to a bad first owner.']
# Prediction Alice worked with him and he became more obedient.
# Option 0 Alice had no intentions of helping him.
# Option 1 Alice worked with him and he became more obedient.
# Sentiment of 0 0.0
# Sentiment of 1 0.45
# Average context sentiment 0.1125
# Context ['Yasmine was all alone with a migraine.', 'She did not know what to do or how to make the pain go away.', 'She remembered what her mother used to do for her during migraines.', 'She went to the sink and prepared a warm towel.']
# Prediction She pressed the towel to her forehead.
# Option 0 She put the towel in the dirty laundry.
# Option 1 She pressed the towel to her forehead.
# Sentiment of 0 -0.6
# Sentiment of 1 0.0
# ...
# Context ["Stephanie had just moved into her boyfriend's apartment.", "She didn't like the way he decorated.", 'She tried to drop subtle hints but he ignored all of them.', 'Finally she decided to make some changes while he was at work.']
# Prediction Her boyfriend redecorated her apartment.
# Option 0 Her boyfriend was not impressed.
# Option 1 Her boyfriend redecorated her apartment.
# Sentiment of 0 -0.5
# Sentiment of 1 0.0
# Average context sentiment -0.125
# Context ['Sadie loved growing tomatoes and peppers in her backyard.', 'Sadie would grind them together and make a delicious salsa.', 'She began selling it to people to use at their parties.', 'Her business started expanding rapidly as demand increased.']
# Prediction Sadie now makes salsa as her full time job.
# Option 0 Sadie now makes salsa as her full time job.
# Option 1 Sadie never grew tomatoes again.
# Sentiment of 0 0.35
# Sentiment of 1 0.0
# Average context sentiment 0.0875
# Context ['My mom came home sad today.', "I decided to ask her if she's alright.", "She didn't say anything.", 'Being considerate, I decided to leave her alone.']
# Prediction She eventually came to me and apologized for being rude.
# Option 0 I walked toward her and screamed in her face for being rude.
# Option 1 She eventually came to me and apologized for being rude.
# Sentiment of 0 -0.3
# Sentiment of 1 -0.3
# Average context sentiment -0.15
# Context ['Sam was on the elevator to reach his apartment.', 'All of a sudden, the lights in the elevator went out.', 'He was stuck on the elevator with the power out.', 'Sam texted his girlfriend while he waited in the elevator.']
# Prediction Sam loved that elevator.
# Option 0 Sam loved that elevator.
# Option 1 Sam was eventually let out when the power came back.
# Sentiment of 0 0.7
# Sentiment of 1 0.0
# Average context sentiment 0.175
# Context ['Tom slept through his alarm and was late for work today.', 'His boss told him he has been late multiple times this month.', 'He told Tom to figure something out so he shows up on time.', 'Tom went out and bought three alarm clocks.']
# Prediction Now Tom is late due to time spent turning off the alarms.
# Option 0 Tom gave the clocks to his sister who was always late for work.
# Option 1 Now Tom is late due to time spent turning off the alarms.
# Sentiment of 0 -0.3
# Sentiment of 1 -0.17500000000000002
# Average context sentiment -0.11875
# Context ['Tim was fishing on the bank.', 'He felt a bit on his line.', 'He yanked up real hard.', 'The fish on his line flew out of the water.']
# Prediction It was the biggest fish he had ever caught.
# Option 0 He thought fishing was boring.
# Option 1 It was the biggest fish he had ever caught.
# Sentiment of 0 -1.0
# Sentiment of 1 0.0
# Average context sentiment -0.25
# Context ['Susan looked forward to Sunday.', 'Every Sunday Susan and her grandpa would take a walk into town.', 'When they got to town they would stop at the ice cream shop.', 'Susan and her grandpa always order a Hot fudge sundae.']
# Prediction Susan really hates eating hot fudge sundaes with her grandpa.
# Option 0 Susan really hates eating hot fudge sundaes with her grandpa.
# Option 1 Today Susan decided to ask for extra fudge on her sundae.
# Sentiment of 0 0.225
# Sentiment of 1 0.0
# Average context sentiment 0.05625
# Context ['Wendell always wanted to learn how to swim.', 'He signed up for swimming lessons at his local YMCA.', 'He felt nervous getting in the water for the first time.', 'Eventually, he got the hang of propelling himself in the water.']
# Prediction Wendell became a great swimmer.
# Option 0 Wendell became a great swimmer.
# Option 1 Wendell continued to get worse at swimming.
# Sentiment of 0 0.8
# Sentiment of 1 -0.4
# Average context sentiment 0.1
# Context ['Coach Reid implemented a rigorous boot camp for preseason.', 'Every night the players would do a series of military exercises.', 'The coaches hoped this would instill discipline within the players.', 'Although at the time, the players resented it, they grew as a team.']
# Prediction Discipline in sports is an important thing to learn.
# Option 0 The coach ate his vegetables.
# Option 1 Discipline in sports is an important thing to learn.
# Sentiment of 0 0.0
# Sentiment of 1 0.4
# Average context sentiment 0.1
# Context ['At school, Joanie heard some girls talking about church.', 'They asked Joan if she was a Christian.', 'When Joanie shook her head, the girls shunned her.', 'Joanie told her mom about it.']
# Prediction Joanie's mom was happy she had made some friends.
# Option 0 Joanie's mom was happy she had made some friends.
# Option 1 Joanie's mom told her not to worry about such judgmental people.
# Sentiment of 0 0.8
# Sentiment of 1 0.0
# Average context sentiment 0.2
# Context ['Sue was a very fit woman.', 'She worked out on a daily basis.', 'Sue found out she was expecting a baby.', 'She continued to workout during the pregnancy.']
# Prediction Sue continued to drink alcohol.
# Option 0 Sue's doctors did not approve.
# Option 1 Sue continued to drink alcohol.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Kelly and her friends wanted to try the new Asian fusion restaurant.', 'They absolutely loved Asian food.', 'As soon as they walked in the atmosphere was great.', 'The food was delicious.']
# Prediction They were happy they had come to the new restaurant.
# Option 0 They were angry they had come to the new restaurant.
# Option 1 They were happy they had come to the new restaurant.
# Sentiment of 0 -0.18181818181818182
# Sentiment of 1 0.4681818181818182
# Average context sentiment 0.0715909090909091
# Context ['Harris was poor.', 'He decided to rob a bank.', 'He held up the bank at gunpoint and stole thousands of dollars.', 'He escaped in his getaway car.']
# Prediction Harris decided to toss the money in the lake.
# Option 0 Harris could not outrun the police and was caught.
# Option 1 Harris decided to toss the money in the lake.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Amy was happy it was Saturday.', "She didn't want to go to school and face her friends.", 'They All wanted to hear about the big game.', 'That was the last thing she wanted to discuss.']
# Prediction Amy called her friends as soon as she could.
# Option 0 Amy called her friends as soon as she could.
# Option 1 Amy avoided her friends and talking about the big game.
# Sentiment of 0 0.0
# Sentiment of 1 -0.2
# Average context sentiment -0.05
# Context ['Gina and her friends were at the library at school.', 'But the librarian had left, and locked the door.', 'The girls sat on the floor in the hallway and waited.', 'Soon, they were concerned she may not be returning.']
# Prediction Gina decided to call for help.
# Option 0 Gina didn't care if the librarian returned.
# Option 1 Gina decided to call for help.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Bani heard that the museum had a dinosaur exhibit.', 'He begged his mom to take him.', 'She took him the very next day.', 'Bani excitedly walked through the exhibit.']
# Prediction Bani was upset that he had to go to the museum.
# Option 0 Bani was fascinated by all the dinosaurs.
# Option 1 Bani was upset that he had to go to the museum.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Ben was shopping at a walmart.', 'He was looking for anything that seemed cool to him.', 'Ben noticed a large adult kite was on sale.', 'He bought the kite and went back home.']
# Prediction Ben flew his kite in the backyard all night!
# Option 0 Ben was upset he'd gone shopping.
# Option 1 Ben flew his kite in the backyard all night!
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ["Alison's fan had three settings.", 'When she put it on the most powerful one it wobbled.', "Her new boyfriend didn't know this and put it as such.", 'It wobbled to the point of spinning off.']
# Prediction Alison ate an ice cream sandwich.
# Option 0 Alison ate an ice cream sandwich.
# Option 1 Her boyfriend felt bad that he broke the fan.
# Sentiment of 0 0.0
# Sentiment of 1 -0.6999999999999998
# Average context sentiment -0.17499999999999996
# Context ['Jessica likes to get coffee before work.', 'One morning she was running five minutes late.', 'When she got to the coffee shop, the line was very long.', 'She had to go to work without coffee that morning.']
# Prediction She felt energized and alert all morning.
# Option 0 She felt energized and alert all morning.
# Option 1 She was frustrated all morning.
# Sentiment of 0 0.0
# Sentiment of 1 -0.7
# Average context sentiment -0.175
# Context ['I screamed into the void to see if there were any more survivors.', 'Between the echos of my yell I thought I heard something.', 'I walked toward the sound of the voice.', 'It grew louder the closer I got.']
# Prediction There weren't any more survivors.
# Option 0 There weren't any more survivors.
# Option 1 I saw the face of a young lady crying for my help.
# Sentiment of 0 0.5
# Sentiment of 1 -0.05
# Average context sentiment 0.1125
# Context ['I went driving the other day.', 'After putting the key in, I turned the ignition.', "It wasn't long before I was on the road!", 'I went to a grocery store to see if there were any deals.']
# Prediction I did not food, so I drove straight home.
# Option 0 There were, and I bought food and then went home.
# Option 1 I did not food, so I drove straight home.
# Sentiment of 0 0.0
# Sentiment of 1 0.2
# Average context sentiment 0.05
# Context ['Sarah wanted to build her new Lego kit.', 'She unpacked all of the pieces.', 'She read the directions.', 'She followed the steps to build the kit.']
# Prediction Sarah was very methodical when using the Legos.
# Option 0 Sarah was very methodical when using the Legos.
# Option 1 Sarah was very sloppy when using her Legos.
# Sentiment of 0 0.2
# Sentiment of 1 -0.5416666666666667
# Average context sentiment -0.08541666666666668
# Context ['One afternoon Sallie took her dog, Gibby, to the dog park.', 'Gibby was always afraid of the other dogs at the park.', 'But this time, she met another dog who was also just as afraid.', 'Both dogs greeted each other with wagging tails.']
# Prediction Sallie was glad that Gibbie made a friend.
# Option 0 Sallie was glad that Gibbie made a friend.
# Option 1 Sallie punished Gibbie.
# Sentiment of 0 0.5
# Sentiment of 1 0.0
# Average context sentiment 0.125
# Context ['Mike would go to his friends house.', 'They would play Sega for hours.', 'All different kinds of games.', "After hours he'd finally head home."]
# Prediction Mike loved going to his friends' house.
# Option 0 Mike loved going to his friends' house.
# Option 1 Mike stole the Sega to sell it for cocaine.
# Sentiment of 0 0.7
# Sentiment of 1 0.0
# Average context sentiment 0.175
# Context ['I had to reprimand two employees that worked at different locations.', 'I hated doing it and thought the matter was done with.', 'Weeks later, one left a message about a question on paperwork.', 'I phoned with: "It\'s me" and she said horrible things about me.']
# Prediction I gave her a raise, and a promotion.
# Option 0 I was forced to fire the employee.
# Option 1 I gave her a raise, and a promotion.
# Sentiment of 0 -0.30000000000000004
# Sentiment of 1 0.0
# Average context sentiment -0.07500000000000001
# Context ['Hannah had a beautiful cat that she loved very much.', 'However, she noticed that her cat was getting very old.', 'One day, her cat ran away and never came back.', 'Hannah was devastated.']
# Prediction She never saw her beautiful cat again.
# Option 0 She never saw her beautiful cat again.
# Option 1 She found her cat hidden under the couch.
# Sentiment of 0 0.85
# Sentiment of 1 -0.16666666666666666
# Average context sentiment 0.17083333333333334
# Context ["Amy's class was going to the museum on a field trip.", 'Amy was excited to view the King Tut exhibit.', 'Amy asked the information desk where to find the exhibit.', 'The lady informed her the Exhibit left the month before.']
# Prediction Amy became happy.
# Option 0 Amy became happy.
# Option 1 Amy became sad.
# Sentiment of 0 0.8
# Sentiment of 1 -0.5
# Average context sentiment 0.07500000000000001
# Context ["Larry hasn't eaten all day.", "He is afraid he doesn't have any food at home to eat.", 'Finally he notices that he has instant noodles in his cupboard.', 'He boils water to cook the noodles.']
# Prediction Larry orders a pizza.
# Option 0 He has noodles for dinner.
# Option 1 Larry orders a pizza.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Tim got his first job.', 'But it required him to sit for long hours.', 'Tim wanted to spend the money he earned on a car.', 'But instead, he had to spend it on back surgery.']
# Prediction His back felt much better after surgery.
# Option 0 His back felt much better after surgery.
# Option 1 Tim decided to buy a boat.
# Sentiment of 0 0.25
# Sentiment of 1 0.0
# Average context sentiment 0.0625
# Context ['Carl sent a valentine to the girl he liked named Katie.', 'But the college mailroom accidentally delivered it to the wrong Katie!', 'The wrong Katie was delighted by the valentine she thought was hers.', 'Out of pity, Carl took her on a date that night.']
# Prediction Carl and Stacey enjoyed their date.
# Option 0 Carl and Stacey enjoyed their date.
# Option 1 Katie found out and then was very hurt.
# Sentiment of 0 0.5
# Sentiment of 1 0.2
# Average context sentiment 0.175
# Context ['Derek was driving at night.', 'Suddenly his car buckled and he was forced to pull over.', 'There was smoke coming from under the hood.', 'He noticed this and got out of the car quickly.']
# Prediction It took 4 hours for his car to cool off so he could go home.
# Option 0 He walked away, and never looked back.
# Option 1 It took 4 hours for his car to cool off so he could go home.
# Sentiment of 0 0.0
# Sentiment of 1 0.35
# Average context sentiment 0.0875
# Context ['Rex had always loved birds.', 'One day his friend recommended they go birding at a local park.', 'Rex and his friend saw finches, sparrows, and other birds.', 'They talked about all the birds they had seen over ice cream later.']
# Prediction They had fun.
# Option 0 They had fun.
# Option 1 Rex decided that he never wanted to do that again.
# Sentiment of 0 0.3
# Sentiment of 1 0.0
# Average context sentiment 0.075
# Context ['My grandma was on her deathbed.', 'She told me to always take out time for the little things.', 'I try to live this daily.', 'I try to enjoy the things people normally take for granted.']
# Prediction I thank my grandma for my giving me my life's philosophy.
# Option 0 I never liked the things my grandma said.
# Option 1 I thank my grandma for my giving me my life's philosophy.
# Sentiment of 0 -0.3
# Sentiment of 1 0.0
# Average context sentiment -0.075
# Context ['Tina invited Todd to dinner.', 'She went to the fish market for something special.', 'She was frightened by all the fish eyes staring at her.', 'She left without buying anything.']
# Prediction They had fish for dinner that night with extra fish eyes.
# Option 0 Tina decided they'd eat out for dinner.
# Option 1 They had fish for dinner that night with extra fish eyes.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
# Context ['Wallace had a passion for gardening.', 'He had been gardening since he was ten years of age.', 'Wallace followed his passion well into his college years.', 'Wallace graduated from college with a degree in biology.']
# Prediction He used his knowledge to become a professional taxi driver.
# Option 0 He used his knowledge to become a professional gardener.
# Option 1 He used his knowledge to become a professional taxi driver.
# Sentiment of 0 0.1
# Sentiment of 1 0.1
# Average context sentiment 0.05
# Context ['Tam felt defeated as she looked at her lawn covered with Dandelions.', 'Kids came to her daycare, one of them picking a Dandelion for Tam.', 'Tam had an idea.', 'Before they left, Tam told the kids to pick a bouquet for their moms.']
# Prediction The kids picked bouquets.
# Option 0 Tam took the kids to Canada.
# Option 1 The kids picked bouquets.
# Sentiment of 0 0.0
# Sentiment of 1 0.0
# Average context sentiment 0.0
#
# 2016 test accuracy:
# 0.5702832709780866

# %% [markdown]
# ### Train a classifier using BERT embeddings.
# **Important: Go to `Runtime > Change runtime type` and make sure you have a GPU in your runtime before completing this section.**
#
# In this section, you'll train a classifier to predict which ending is correct. Ideally, you'd finetune a large pre-trained language model (a.k.a. BERT) on the classification task, but since finetuning is pretty slow, we'll instead pre-compute BERT embeddings for each story context and for each possible ending. We'll then train a new model on top of these pre-computed embeddings.
#
# **But how do we do classification if the training set only contains positive examples?**
#
# We invent negative examples! At each training step, we pick a random set of 5th sentences from all of the 5th sentences in the training set to act as distractors.
# The hyperparameter `NUM_CANDIDATES` sets the number of distractors that are chosen. If `NUM_CANDIDATES` is set to 50, that means we do 50-way classification in our loss.
#
# **What should the neural network look like?**
#
# The goal of the neural network is to project the embedding of the context into the embedding space of endings.
# This way at evaluation time, we can compute a score for each candidate ending by taking the dot-product between the predicted embedding returned by the neural network and the embeddings of each ending. Whichever ending has the highest score wins.
#
# You are free to implement the neural network however you'd like, but you'll probably want to start with a simple [MLP](https://www.tensorflow.org/guide/keras/overview#sequential_model). (You'll want to omit the final softmax layer since that's taken care of for you in the train loop.)
#
#
# **What you should complete in this section:**
# * **Fill in the `get_model` function. Try at least two different architectures (varying the number of layers, hidden size, activation functions, etc.) and include a discussion of their relative performance in your report.**
# * **Try training with at least two different hyperparameter settings to see if you can improve performance. Include a discussion of the experiments you tried and their performance in your report.**

# %% [markdown]
# #### Compute/retrieve BERT embeddings.
#
# Note that we've commented out the lines to generate the BERT embeddings and instead provided you with pre-computed files since running BERT on 100k+ sequences can take a few hours.
#
# However, you are welcome to uncomment and experiment with computing the embeddings yourself.

# %%
from transformers import BertTokenizer, BertModel
import torch

def load_bert():
  tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
  model = BertModel.from_pretrained('bert-base-uncased')
  return model, tokenizer

def bert_embedding(text):
  inputs_ids = TOKENIZER.encode(text)
  input_ids = torch.tensor(inputs_ids).unsqueeze(0)  # Batch size 1

  _, merged_embedding = BERT_MODEL(input_ids)
  return merged_embedding.detach().numpy()
  
def get_train_embeddings(data):
  """Computes embeddings for each example in the provided train set."""
  context_embeddings = []
  ending_embeddings = []
  print('Starting')
  # for example in tqdm(data, desc='Computing BERT embeddings '):
  for idx, example in enumerate(data):
    if idx % 20 == 0:
      print('{}/{}'.format(idx+1, len(data)))
      print(' '.join(example['story']))
    context_embedding = bert_embedding(' '.join(example['story'][:4]))
    ending_embedding = bert_embedding(example['story'][4])

    context_embeddings.append(context_embedding)
    ending_embeddings.append(ending_embedding)
  context_embeddings = np.concatenate(context_embeddings, axis=0)
  ending_embeddings = np.concatenate(ending_embeddings, axis=0)
  return context_embeddings, ending_embeddings

def get_valid_embeddings(data):
  """Computes embeddings for each example in the provided validation set."""
  context_embeddings = []
  ending_0_embeddings = []
  ending_1_embeddings = []
  for example in tqdm(data, desc='Computing BERT embeddings '):
    context_embedding = bert_embedding(' '.join(example['context'][:4]))
    ending_0_embedding = bert_embedding(example['options'][0])
    ending_1_embedding = bert_embedding(example['options'][1])

    context_embeddings.append(context_embedding)
    ending_0_embeddings.append(ending_0_embedding)
    ending_1_embeddings.append(ending_1_embedding)

  context_embeddings = np.concatenate(context_embeddings, axis=0)
  ending_0_embeddings = np.concatenate(ending_0_embeddings, axis=0)
  ending_1_embeddings = np.concatenate(ending_1_embeddings, axis=0)
  return context_embeddings, ending_0_embeddings, ending_1_embeddings

# These are the lines I used to generate BERT embeddings. Since, they are slow
# to compute, we've provided the outputs as .pkl files.
# BERT_MODEL, TOKENIZER = load_bert()
# train_context_embs, train_ending_embs = get_train_embeddings(train_data)
# valid_2016_context_embs, valid_2016_ending_0_embs, valid_2016_ending_1_embs = get_valid_embeddings(valid_2016_data)
# valid_2018_context_embs, valid_2018_ending_0_embs, valid_2018_ending_1_embs = get_valid_embeddings(valid_2018_data)
# test_2016_context_embs, test_2016_ending_0_embs, test_2016_ending_1_embs = get_valid_embeddings(test_2018_data)

# %%
# !gsutil cp gs://cis700_shared_data/rocstories_data/rocstories_train.pkl /content/rocstories_train.pkl
with open('/content/rocstories_train.pkl', 'rb') as f:
  data = pickle.load(f)
  train_context_embs = data['contexts']
  train_ending_embs = data['endings']

# !gsutil cp gs://cis700_shared_data/rocstories_data/rocstories_valid_2016.pkl /content/rocstories_valid_2016.pkl
with open('/content/rocstories_valid_2016.pkl', 'rb') as f:
  data = pickle.load(f)
  valid_2016_context_embs = data['contexts']
  valid_2016_ending_0_embs = data['endings_0']
  valid_2016_ending_1_embs = data['endings_1']

# !gsutil cp gs://cis700_shared_data/rocstories_data/rocstories_valid_2018.pkl /content/rocstories_valid_2018.pkl
with open('/content/rocstories_valid_2018.pkl', 'rb') as f:
  data = pickle.load(f)
  valid_2018_context_embs = data['contexts']
  valid_2018_ending_0_embs = data['endings_0']
  valid_2018_ending_1_embs = data['endings_1']

# !gsutil cp gs://cis700_shared_data/rocstories_data/rocstories_test_2016.pkl /content/rocstories_test_2016.pkl
with open('/content/rocstories_test_2016.pkl', 'rb') as f:
  data = pickle.load(f)
  test_2016_context_embs = data['contexts']
  test_2016_ending_0_embs = data['endings_0']
  test_2016_ending_1_embs = data['endings_1']

# %% [markdown]
# #### Train a model

# %%
def get_batch(batch_size, num_candidates):
  """Returns a single training batch.
  
  Returns:
  batch_inputs: [batch_size, embedding_size] matrix of context embeddings.
  batch_candidates: [num_candidates, embedding_size] matrix of embeddings of 
    candidate 5th sentence embeddings. The groundtruth 5th sentence for the ith
    example in batch_inputs is in the ith row of batch_candidates.
  labels: [batch_size] For each example in batch_inputs, the index of the true
    5th sentence in batch_candidates.
  """
  if num_candidates < batch_size:
    raise ValueError(
        'At minimum the number of candidates is at least all of the other 5th '
        'sentences in the batch.')
    
  batch_inputs = []
  batch_candidates = []
  batch_labels = []
  for i in range(batch_size):
    rand_ex_index = random.randint(0, train_context_embs.shape[0]-1)
    batch_inputs.append(train_context_embs[rand_ex_index, :])
    batch_candidates.append(train_ending_embs[rand_ex_index, :])
    # The true next embedding is in the ith position in the candidates
    batch_labels.append(i)

  # Increase the number of "distractor" candidates to num_candidates.
  for i in range(num_candidates - batch_size):
    rand_ex_index = random.randint(0, train_context_embs.shape[0]-1)
    batch_candidates.append(train_ending_embs[rand_ex_index, :])

  batch_inputs = np.stack(batch_inputs, axis=0)
  batch_candidates = np.stack(batch_candidates, axis=0)
  return batch_inputs, batch_candidates, batch_labels

def predict_based_on_bert_classifier(
    context_embs, ending_0_embs, ending_1_embs, model):
  """Returns a list of predictions based on model."""
  predicted_embs = model(context_embs)
  
  predictions = []
  for idx in range(predicted_embs.shape[0]):
    pred_emb = predicted_embs[idx, :]
    score_0 = np.dot(pred_emb, ending_0_embs[idx, :])
    score_1 = np.dot(pred_emb, ending_1_embs[idx, :])
    predictions.append(score_0 < score_1)
  return predictions
  
def get_model():
  """Returns a Keras model.
  The model should input a [batch_size, embedding_size] tensor and output a new
  [batch_size, embedding_size] tensor. At it's simplest, it could just be a
  single dense layer. You should experiment with adding layers, changing the
  activation function, or otherwise modifying the architecture defined below.
  See:
  https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense
  
  """

  # This is an example of a very simple network consisting of a single nonlinear
  # layer followed by a linear projection back to the BERT embedding size.
  model = tf.keras.Sequential()
  model.add(tf.keras.layers.Dense(512, activation="relu"))
  tf.keras.layers.Dropout(0.5, noise_shape=None, seed=None)
  model.add(tf.keras.layers.Dense(128, activation="relu"))
  model.add(tf.keras.layers.Dense(768, activation="linear"))
  
  return model

# %% [markdown]
# You should experiment with the hyperparamters (IN ALL_CAPS) below to see if you can improve performance. I was able to get 67% validation accuracy with the provided values and using a two-layer network with a ReLU nonlinearity between the layers. Training took about an hour.

# %%
#### HYPERPARAMETERS ####
NUM_TRAIN_STEPS = 40000  # How many step to train for.
BATCH_SIZE = 32  # Number of examples used in step of training.
NUM_CANDIDATES = 60  # Number of candidate 5th sentences classifier must decide between.
LEARNING_RATE = 0.002  # Learning rate.
# If your loss is barely going down, learning rate might be too small.
# If your loss is jumping around, it might be too big.

# You may experiment with other optimizers or loss functions if you'd like.
optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
model = get_model()

# Iterate over the batches of a dataset.
for train_step in range(NUM_TRAIN_STEPS):
  with tf.GradientTape() as tape:
    batch_inputs, batch_candidates, batch_labels = get_batch(BATCH_SIZE, NUM_CANDIDATES)

    # Predicted 5th sentence embedding for each batch position/
    outputs = model(batch_inputs)
    # The logits will be batch_size * num_candidates, giving a score for each
    # candidate 5th sentence. We'd like the true 5th sentence to have the
    # highest score.
    logits = tf.matmul(outputs, batch_candidates, transpose_b=True)
    # Loss value for this minibatch
    loss_value = loss_fn(batch_labels, logits)

  grads = tape.gradient(loss_value, model.trainable_weights)
  optimizer.apply_gradients(zip(grads, model.trainable_weights))

  if train_step % 100 == 0:
    print('Step {}, batch_train_loss={}'.format(train_step, loss_value))
  if train_step % 1000 == 0:
    predictions_2016 = predict_based_on_bert_classifier(valid_2016_context_embs, valid_2016_ending_0_embs, valid_2016_ending_1_embs,model)
    predictions_2018 = predict_based_on_bert_classifier(valid_2018_context_embs, valid_2018_ending_0_embs, valid_2018_ending_1_embs,model)
    
    print('2016 validation accuracy: {}'.format(compute_accuracy(valid_2016_data, predictions_2016)))
    print('2018 validation accuracy: {}'.format(compute_accuracy(valid_2018_data, predictions_2018)))

# %% [markdown]
# **What is overfitting?**
#
# You may have observed when training that your validation accuracy goes up for a while and then eventually starts going down. This is called overfitting, because your model is learning to be really good at classifying examples from the training set at the expense of dong a good job at classifying usneen exampes in the validation set. You could prevent overfitting by automatically stopping training when the validation accuracy has not improved in X steps (where X is another hyperparamter you'd have to decide upon).

# %% [markdown]
# #### Evaluate your model

# %%
predictions_2016 = predict_based_on_bert_classifier(
    valid_2016_context_embs, valid_2016_ending_0_embs, valid_2016_ending_1_embs,
    model)
print('\n2016 validation accuracy: ' )
print(compute_accuracy(valid_2016_data, predictions_2016))

predictions_2018 = predict_based_on_bert_classifier(
    valid_2018_context_embs, valid_2018_ending_0_embs, valid_2018_ending_1_embs,
    model)
print('\n2018 validation accuracy: ' )
print(compute_accuracy(valid_2018_data, predictions_2018))

predictions_2016 = predict_based_on_bert_classifier(
    test_2016_context_embs, test_2016_ending_0_embs, test_2016_ending_1_embs,
    model)
print('\n2016 test accuracy: ' )
print(compute_accuracy(test_2016_data, predictions_2016))

# %% [markdown]
# ### Train classifier on validation set
# Part of the difficulty (and interestingness) of the ROCStories task is that the training set contains only positive examples. However, researchers have found that accuracies as high as 90% are possible if you cheat and train a supervised classifier using the examples with both positive and negative examples found in the validation set.
#
# **Run the train code below, experimenting with at least twos variant, either modifying the hyperparamters or model architecture. You could also try to find a way to take advantage of the large unlabeled dataset in addition to the labeled data. Include a discussion in your report.**

# %%
def get_batch_from_valid(batch_size, inputs, labels):
  """Returns a single training batch extracted form the validation set.

  Inputs:
  batch_size: The batch size.
  inputs: [dataset_size, 2*embedding_size] matrix of all inputs in the training
    set.
  labels: [dataset_size] for each example, 0 if example has the incorrect ending
    embedding, 1 if it has the correct ending embedding.
  
  Returns:
  batch_inputs: [batch_size, 2*embedding_size] matrix of embeddings (each
    embedding is a context embedding concatenated with an ending embedding).
  labels: [batch_size] For each example in batch_inputs, contains either 0 or 1,
    indicating whether the 5th ending is the correct one.
  """
  batch_inputs = []
  batch_labels = []
  for i in range(batch_size):
    rand_ex_index = random.randint(0, inputs.shape[0]-1)    
    batch_inputs.append(inputs[rand_ex_index, :])
    batch_labels.append(labels[rand_ex_index])
    
  batch_inputs = np.stack(batch_inputs, axis=0)
  return batch_inputs, batch_labels

# Each input example consists of a context_embedding concatenated with an ending embedding.
def build_dataset():
  """Builds a dataset out of the validation set examples.

  Each example in valid_2016 and valid_2018 becomes two exampes in this new 
  dataset:
  * one where ending_0's embedding is concatenated to the context embedding
  * one where ending_1's embedding is concatenated to the context embedding

  The label for each example is 1 if the correct ending's embedding is present,
  0 if the incorrect ending's embedding is present.

  Returns:
  all_inputs: [new_dataset_size, embedding_size*2]
  all_labels: [new_dataset_size]
  """
  inputs_2016 = tf.concat(
      [tf.concat([valid_2016_context_embs, valid_2016_ending_0_embs], axis=-1),
      tf.concat([valid_2016_context_embs, valid_2016_ending_1_embs], axis=-1)], axis=0)
  labels = [ex['label'] for ex in valid_2016_data]
  labels_2016 = labels + [1 - label for label in labels]

  inputs_2018 = tf.concat(
      [tf.concat([valid_2018_context_embs, valid_2018_ending_0_embs], axis=-1),
      tf.concat([valid_2018_context_embs, valid_2018_ending_1_embs], axis=-1)], axis=0)
  labels = [ex['label'] for ex in valid_2018_data]
  labels_2018 = labels + [1 - label for label in labels]

  all_inputs = tf.concat([inputs_2016, inputs_2018], axis=0)
  all_labels = labels_2016 + labels_2018

  return all_inputs, all_labels

def predict_based_on_bert_binary_classifier(
    context_embs, ending_0_embs, ending_1_embs, model):
  """Returns a list of predictions based on binary classification model."""
  scores_ending_0 = model(tf.concat([context_embs, ending_0_embs], -1))
  scores_ending_1 = model(tf.concat([context_embs, ending_1_embs], -1))
  predictions = tf.greater(scores_ending_0, scores_ending_1)[:, 1]
  return predictions

def get_binary_classifier():
  """Returns a Keras model.
  The model should input a [batch_size, 2*embedding_size] tensor and output a
  [batch_size, 2] tensor. The final final dimension needs to be 2 because we are
  doing binary classification.
  
  You should experiment with modifying the architecture below.
  See:
  https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense
  
  """

  model = tf.keras.Sequential()
  model.add(tf.keras.layers.Dense(1000, activation="relu"))
  model.add(tf.keras.layers.Dense(128, activation="relu"))
  tf.keras.layers.Dropout(0.5, noise_shape=None, seed=None)
  model.add(tf.keras.layers.Dense(2, activation="linear"))
  
  return model

# %%
NUM_TRAIN_STEPS = 30000  # How many step to train for.
BATCH_SIZE = 32  # Number of examples used in step of training.
LEARNING_RATE = 0.001  # Learning rate.

NUM_TRAIN_EXAMPLES = 6000 # How many examples from the valid set to use for training.
# The remainder will be placed into a new valid set.

# You should with varying NUM_TRAIN_EXAMPLES. If it is larger, you will train a 
# better model, but you will have fewer examples available your validation set
# for tuning other hyperparameters.
all_inputs, all_labels = build_dataset()
train_inputs = all_inputs[:NUM_TRAIN_EXAMPLES, :]
train_labels = all_labels[:NUM_TRAIN_EXAMPLES]
valid_inputs = all_inputs[NUM_TRAIN_EXAMPLES:, :]
valid_labels = all_labels[NUM_TRAIN_EXAMPLES:]

# You may experiment with other optimizers or loss functions if you'd like.
optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

model_2 = get_binary_classifier()

# Iterate over the batches of a dataset.
for train_step in range(NUM_TRAIN_STEPS):
  with tf.GradientTape() as tape:
    batch_inputs, batch_labels = get_batch_from_valid(
        BATCH_SIZE, train_inputs, train_labels)

    logits = model_2(batch_inputs)
    loss_value = loss_fn(batch_labels, logits)

  grads = tape.gradient(loss_value, model_2.trainable_weights)
  optimizer.apply_gradients(zip(grads, model_2.trainable_weights))

  if train_step % 100 == 0:
    batch_acc = sum(tf.equal(batch_labels, tf.argmax(logits, axis=-1)).numpy()) / BATCH_SIZE
    print('Step {0}, batch_loss={1:.5f}, batch_acc={2:.3f}'.format(
        train_step, loss_value, batch_acc))
  if train_step % 1000 == 0:
    valid_logits = model_2(valid_inputs)
    num_correct = sum(tf.equal(valid_labels, tf.argmax(valid_logits, axis=-1)).numpy())
    print('Validation accuracy: {0:.3f}'.format(num_correct / len(valid_labels)))

# %%
# We can no longer fairly evaluate on the 2016 and 2018 validation sets since
# they've been used for training. Instead, we only evaluate on the 2016 test set.

predictions_2016 = predict_based_on_bert_binary_classifier(
    test_2016_context_embs, test_2016_ending_0_embs, test_2016_ending_1_embs,
    model_2)
print('\n2016 test accuracy: ' )
print(compute_accuracy(test_2016_data, predictions_2016))

# %% [markdown]
# # Extra Credit
# For extra credit, make an account on [Codalab](https://competitions.codalab.org/) and submit your best model's outputs to the [Winter 2018 leaderboard](https://competitions.codalab.org/competitions/15333#participate-submit_results). You'll need to download the Winter 2018 CSV and create BERT embeddings for it.
#
# **If you choose to do the extra credit, please take a screenshot of the Codalab leaderboard  (including your submission) and paste it into your report. Your report should also include a description of the method that you used in your submission.**
